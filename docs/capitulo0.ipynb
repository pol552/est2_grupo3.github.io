# %% [markdown]
# #
# <head>
#     <link rel="preconnect" href="https://fonts.googleapis.com">
#     <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
#     <link href="https://fonts.googleapis.com/css2?family=Poppins:ital,wght@0,100;0,300;1,100&display=swap" rel="stylesheet">
# </head>
#
# <style>
#     div{
#         font-family: 'Poppins', sans-serif;
#     }
#     /*ESTILOS PORTADA DE CAPITULO*/
#     #capitulo {
#     text-align: center;
#     line-height: 100px;
#     height: 100px;
#     background-color: #009929;
#     color: white;
#     font-size: 50px;
#     padding: 5px;
#     text-shadow: 2px 2px 2px rgba(0, 0, 0, 0.5); /* Sombra del texto */
#     }
#
#     #numero {
#         font-size: 90px;
#     }
#
#     #titulo {
#         height: 100px;
#         color: black;
#         text-align:justify;
#         font-size: 40px;
#         margin-right:35px;
#         margin-left:20px;
#         margin-top: 20px;
#         margin-bottom:20px;
#         font-weight: bold;
#         text-transform: uppercase;
#         margin-bottom: 30px;
#     }
#
#     #contenido {
#         width: 100%;
#         background-color: #009929;
#         text-align: left;
#         color: #fff;
#         float: left;
#         padding: 5px;
#         padding-left:10px;
#         margin-top:80px;
#         margin-bottom: 10px;
#         font-size: 25px;
#     }
#     #separador {
#         width: 100%;
#         height: 2px;
#         background-color: #009929;
#         border: none;
#     } #indice {
#             column-count: 2; /* Divide el contenido en dos columnas */
#             column-gap: 20px; /* Espaciado entre columnas */
#             margin-top: 20px; /* Espaciado superior del índice */
#         }
#     #indice-container {
#         display: inline-block;
#     }
#     #indice ul {
#         list-style: none;
#         padding: 0;
#     }
#     #indice li {
#         break-inside: avoid; /* Evita que los elementos de la lista se separen entre columnas */
#     }
#     /* FIN ESTILOS PORTADA DE CAPITULO*/
#     /*ESTILOS TITULOS DEL CAPITULO*/
#     .indice_titulo{
#         display:flex;
#         color: #009929;
#     }
#     .indice_titulo span{
#         display: inline-block;
#         margin-top: 5px;
#         font-weight: normal;
#     }
#     span.section-number {
#         background-color: #009929;
#         border-radius: 50%;
#         color: white;
#         font-weight: bold;
#         padding: 0.5em;
#         display: inline-flex;
#         justify-content: center;
#         align-items: center;
#         width: 1.5em;
#         height: 1.5em;
#         font-size: 1em;
#         margin-right: 0.5em;
#     }
#     /* FIN ESTILOS TITULOS DEL CAPITULO*/
#     .bold-verde{
#         color: #009929;
#         font-weight: bold;
#     }
#
# </style>
# <div id="capitulo">CAPITULO <span id="numero">0</span></div>
# <div id="titulo"> titulo del capitulo</div>
# <div id="contenido">Contenido del capitulo</div>
# <hr id="separador">
# <div id="indice">
#     <div id="indice-container">
#         <p><span style="color: #009929;">0.0</span>  <strong>MEDIA POBLACIONAL: \( \sigma \) CONOCIDA</strong></p>
#         <ul>
#             <li>Margen de error y estimación por intervalo</li>
#             <li>Consejo práctico</li>
#         </ul>
#     </div>
#     <div id="indice-container">
#         <p><span style="color: #009929;">0.0</span>  <strong>MODELO DE REGRESIÓN LINEAL SIMPLE</strong></p>
#         <ul>
#             <li>Modelo de regresión y ecuación de regresión</li>
#             <li>Ecuación de regresión estimada</li>
#         </ul>
#     </div>
#     <div id="indice-container">
#         <p><span style="color: #009929;">0.0</span>  <strong>MEDIA POBLACIONAL: \( \sigma \) CONOCIDA</strong></p>
#         <ul>
#             <li>Margen de error y estimación por intervalo</li>
#             <li>Consejo práctico</li>
#         </ul>
#     </div>
#     <div id="indice-container">
#         <p><span style="color: #009929;">0.0</span>  <strong>MODELO DE REGRESIÓN LINEAL SIMPLE</strong></p>
#         <ul>
#             <li>Modelo de regresión y ecuación de regresión</li>
#             <li>Ecuación de regresión estimada</li>
#         </ul>
#     </div>
# </div>

# %% [markdown]
# ## <div class = "indice_titulo"><span class="section-number">0.0</span> **Media Poblacional $\sigma$ conocida**</div>

# %% [markdown]
# Desarrollo del capitulo...Es un hecho establecido hace demasiado<span class="bold-verde"> tiempo</span> que un lector se distraerá con el contenido del texto de un sitio mientras que mira su diseño. El **punto** de usar Lorem Ipsum es que tiene una distribución más o menos normal de las letras, al contrario de usar textos como por ejemplo "Contenido aquí, contenido aquí".
# $$
# \sqrt{3x-1}+(1+x)^2
# $$
# "Lorem Ipsum" va a dar por resultado muchos sitios web que usan este texto si se encuentran en estado de desarrollo. Muchas versiones han evolucionado a través de los años, algunas veces por accidente, otras veces a propósito (por ejemplo insertándole humor y cosas por el estilo).

# %% [markdown]
# ### <div class = "indice_titulo">**Margen de error y estimación por intervalo**</div>
# Lorem Ipsum es simplemente el texto de relleno de las imprentas y archivos de texto. Lorem Ipsum ha sido el texto de relleno estándar de las industrias desde el año 1500

# %% [markdown]
# <style>
#         .formulas {
#             background-color: #D4F8B7;
#             padding: 10px;
#             box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
#         }
#         .formula-cuadro {
#             display: flex;
#             align-items: center;
#         }
#
#         .titulo-formula {
#             font-size: 15px;
#             margin-bottom: 10px;
#             font-weight:bold;
#             text-transform: uppercase;
#         }
#
#         .formula {
#             width: 90%;
#             margin-right: 10px;
#         }
#
#         .indice-formula {
#             color: #009929;
#
#         }
# </style>
#
# <div class="formulas">
#         <div class="titulo-formula">Título de la fórmula</div>
#         <div class="formula-cuadro">
#             <div class="formula">
#                 $$ SSE = \sum_{i=1}^{n} (y_i - \hat{y}_i)^2 $$
#             </div>
#         <div class="indice-formula">(0.0)</div>
#         </div>
#     </div>

# %% [markdown]
# <div class="formulas">
#         <div class="titulo-formula">Título de la fórmula</div>
#         <div class="formula-cuadro">
#             <div class="formula">
#                 $$ SSE = \sum_{i=1}^{n} (y_i - \hat{y}_i)^2 $$
#             </div>
#         <div class="indice-formula">(0.0)</div>
#         </div>
#         Donde:
#
# - $ SSE $ es la suma de cuadrados debida al error.
# - $ n $ es el número de observaciones.
# - $ y_i $ son los valores observados.
# - $ \hat{y_i}\ $ son los valores predichos por el modelo.
# </div>

# %% [markdown]
# <style>
#     #con-borde{
#         border-left:3px solid #009929;
#         text-align: center;
#     }
# </style>
# <span style="color: #009929;">**Tabla 3.15**  Titulo de la Tabla</span>
# <div style="display: flex; justify-content: center; align-items: center;">
#     <table style="border-top:3px solid #009929;border-bottom:3px solid #009929;background-color:#D4F8B7;font-size:14px;">
#         <thead>
#             <tr>
#                 <th style="text-align: center; ">Restaurante $i$</th>
#                 <th style="text-align: center;">$x_i$ = Población de estudiantes (miles)</th>
#                 <th style="text-align: center;">Columna 3</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td style="text-align: center;">$\sigma $</td>
#                 <td style="text-align: center;" id="con-borde">1</td>
#                 <td style="text-align: center;" id="con-borde">1</td>
#             </tr>
#             <tr>
#                 <td style="text-align: center;">2</td>
#                 <td style="text-align: center;" id="con-borde">6</td>
#                 <td style="text-align: center;" id="con-borde">1</td>
#             </tr>
#             <tr>
#                 <td style="text-align: center;" >10</td>
#                 <td style="text-align: center;" id="con-borde">7</td>
#                 <td style="text-align: center;" id="con-borde">1</td>
#             </tr>
#             <tr>
#                 <td style="text-align: center;" >8</td>
#                 <td style="text-align: center;" id="con-borde">9</td>
#                 <td style="text-align: center;" id="con-borde">1</td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# <span style="color: #009929;"> **Figura 3.15** Titulo del gráfico </span>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Definir los datos
x = np.array([1, 2, 3, 4, 5])
y = 60 + 5 * x

# Realizar la regresión lineal
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Crear la figura y los ejes
fig, ax = plt.subplots()

# Graficar los datos
ax.scatter(x, y, color="#009929", label="Datos")

# Graficar la recta de regresión
ax.plot(x, intercept + slope * x, color="#98F84A", label=f"Recta de regresión (y = {intercept:.2f} + {slope:.2f}x)")

# Cambiar el color del fondo
ax.set_facecolor("#D4F8B7")

# Pintar el fondo externo del gráfico
fig.patch.set_facecolor('#D4F8B7')

# Colocar el título
ax.set_title("Gráfico de regresión lineal")

# Agregar leyenda
ax.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# <span style="color: #009929;"> **Figura 3.15** Titulo del gráfico </span>

# %%
import matplotlib.pyplot as plt

# Datos para el gráfico de barras
categorias = ['Capital nacional', 'Capital internacional', 'Renta FIja']
valores = [65, 15, 20]

# Crear la figura y los ejes
fig, ax = plt.subplots()

# Ajustar el color de fondo
ax.set_facecolor("#d4f8b7")
# Pintar el fondo externo del gráfico
fig.patch.set_facecolor('#D4F8B7')

# Crear el gráfico de barras
plt.bar(categorias, valores, color='#5CCB5f', edgecolor='black', linewidth=1.5, width=0.45)

# Añadir etiquetas y título con texto en negrita
plt.xlabel('Tipo de Fondo', fontsize=10, fontweight='bold')
plt.ylabel('Frecuencia Porcentual', fontsize=10, fontweight='bold')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# <span style="color: #009929;"> **Figura 3.15** Titulo del gráfico </span>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución normal
media = 68.42
desviacion_estandar = 10

# Generar datos de la distribución normal
x = np.linspace(media - 4 * desviacion_estandar, media + 4 * desviacion_estandar, 1000)
y = norm.pdf(x, media, desviacion_estandar)

# Crear la gráfica
fig, ax = plt.subplots()
ax.plot(x, y, color='#009929')
# Establecer el color de fondo
ax.set_facecolor('#d4f8b7')  
# Pintar el fondo externo del gráfico
fig.patch.set_facecolor('#D4F8B7')
ax.set_xlabel(f'media = {media}', fontsize=12)
ax.set_ylabel('Densidad de Probabilidad', fontsize=12)

# Agregar información sobre la desviación estándar
info_desviacion = f'σ = {desviacion_estandar}'
ax.text(0.6, 0.85, info_desviacion, transform=ax.transAxes, fontsize=12, color='#000')

ax.grid(False)
plt.show()

# %% [markdown]
# <span style="color: #009929;"> **Figura 3.15** Titulo del gráfico </span>

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.gridspec as gridspec

# Datos para el gráfico de pastel
nombres = ['Coke Classic', 'Pepsi', 'Diet Coke', 'Dr. Pepper', 'Sprite']
porcentajes = [38, 26, 16, 10, 10]
colores = ['#5ccb5f', '#98f84a', '#e1ffaf', '#fff', '#e1ffaf']

# Crear el gráfico de pastel sin bordes
fig = plt.figure(figsize=(5, 5))
gs = gridspec.GridSpec(1, 1, width_ratios=[1], height_ratios=[1])
ax = plt.subplot(gs[0])

wedges, texts, autotexts = ax.pie(porcentajes, labels=None, autopct=lambda p: f'{p:.1f}%\n{nombres.pop(0)}', colors=colores)

# Agregar bordes negros a las porciones del gráfico
for wedge in wedges:
    wedge.set_edgecolor('black')
    wedge.set_linewidth(1)

# Configurar el color de fondo externo
fig.patch.set_facecolor('#D4F8B7')

# Centrar el gráfico en la página
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# <style>
#     .ejercicios{
#         color:white;
#         background-color:#009929;
#         padding-left:20px;
#     }
# </style>
# ### <div class = "ejercicios">Ejercicios</div>

# %% [markdown]
# <span style="color: #009929;">**Ejercicio 1.**  </span>Enunciado
